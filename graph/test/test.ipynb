# %%
import torch
import torchvision.models
import hiddenlayer as hl



model = torchvision.models.alexnet()

#graph = Graph(model, torch.zeros([1,3,224,224]))
hl_graph = hl.build_graph(model, torch.zeros([1, 3, 224, 224]))
hl_graph.theme = hl.graph.THEMES["blue"].copy()  # Two options: basic and blue
hl_graph
# Out:
# /data1/panyj/once-for-all/dev_env/lib/python3.6/site-packages/torch/onnx/symbolic_helper.py:680: UserWarning: ONNX export mode is set to inference mode, but operator dropout is set to training  mode. The model will be exported in inference, as specified by the export mode.
#   training_mode + ", as specified by the export mode.")
